# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %%
iris = pd.read_csv('iris_dataset.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
plt.scatter(iris['sepal_length'], iris['sepal_width'])
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')
plt.show()

# %%
x = iris.copy()

# %%
kmeans = KMeans(2)
kmeans.fit(x)
iris['Cluster'] = kmeans.fit_predict(x)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Cluster
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
# [150 rows x 5 columns]

# %%
plt.scatter(iris['sepal_length'], iris['sepal_width'], c = iris['Cluster'], cmap = 'rainbow')
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')
plt.show()

# %%
#standardize the data
x_standard = preprocessing.scale(x)
x_standard
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
kmeans_standard = KMeans(2)
kmeans_standard.fit(x_standard)
standard_data = iris.copy()
standard_data['Cluster'] = kmeans_standard.fit_predict(x_standard)
standard_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Cluster
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        1
# 146           6.3          2.5           5.0          1.9        1
# 147           6.5          3.0           5.2          2.0        1
# 148           6.2          3.4           5.4          2.3        1
# 149           5.9          3.0           5.1          1.8        1
#
# [150 rows x 5 columns]

# %%
plt.scatter(standard_data['sepal_length'], standard_data['sepal_width'], c = standard_data['Cluster'], cmap = 'rainbow')
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')
plt.show()

# %%
wcss = []

for i in range(1, 10):
    kmeans = KMeans(i)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
wcss
# Out:
# [680.8243999999996,
#  152.36870647733915,
#  78.94084142614601,
#  57.317873214285726,
#  46.55405384615384,
#  38.930963049671746,
#  34.299985543844244,
#  30.077530998389694,
#  28.290917748917764]

# %%
#Elbow method
plt.plot(range(1, 10), wcss)
plt.xlabel("Number of clusters")
plt.ylabel('WCSS')
plt.show()

# %%
kmeans_standard = KMeans(3)
kmeans_standard.fit(x_standard)
standard_data['Cluster'] = kmeans_standard.fit_predict(x_standard)

plt.scatter(standard_data['sepal_length'], standard_data['sepal_width'], c = standard_data['Cluster'], cmap = 'rainbow')
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')
plt.show()

# %%
kmeans_standard = KMeans(5)
kmeans_standard.fit(x_standard)
standard_data['Cluster'] = kmeans_standard.fit_predict(x_standard)

plt.scatter(standard_data['sepal_length'], standard_data['sepal_width'], c = standard_data['Cluster'], cmap = 'rainbow')
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')
plt.show()

# %%
iris_answer = pd.read_csv('iris_with_answers.csv')
iris_answer
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_answer.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris_answer['species'] = iris_answer['species'].map({'setosa':0, 'versicolor':1, 'virginica':2})
iris_answer
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
plt.scatter(iris_answer['sepal_length'], iris_answer['sepal_width'], c = iris_answer['species'], cmap = 'rainbow')
plt.show()

# %% [markdown]
# By examing the above graph, I realized that I should cluster them by petal instead of sepal. Petal is a more crucial factor to decide species here.

# %%
plt.scatter(iris_answer['petal_length'], iris_answer['petal_width'], c = iris_answer['species'], cmap = 'rainbow')
plt.show()

# %%
kmeans_standard = KMeans(3)
kmeans_standard.fit(x_standard)
standard_data['Cluster'] = kmeans_standard.fit_predict(x_standard)

plt.scatter(standard_data['petal_length'], standard_data['petal_width'], c = standard_data['Cluster'], cmap = 'rainbow')
plt.xlabel('Petal Width')
plt.ylabel('Petal Length')
plt.show()
